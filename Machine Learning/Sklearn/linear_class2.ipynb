# %%
import pandas as pd
import numpy as np

# %%
mob_train=pd.read_csv("mobile_price_train.csv")

# %%
mob_train.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
mob_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
mob_train.describe().transpose()
# Out:
#                 count        mean          std    min      25%     50%  \
# battery_power  2000.0  1238.51850   439.418206  501.0   851.75  1226.0
# blue           2000.0     0.49500     0.500100    0.0     0.00     0.0
# clock_speed    2000.0     1.52225     0.816004    0.5     0.70     1.5
# dual_sim       2000.0     0.50950     0.500035    0.0     0.00     1.0
# fc             2000.0     4.30950     4.341444    0.0     1.00     3.0
# four_g         2000.0     0.52150     0.499662    0.0     0.00     1.0
# int_memory     2000.0    32.04650    18.145715    2.0    16.00    32.0
# m_dep          2000.0     0.50175     0.288416    0.1     0.20     0.5
# mobile_wt      2000.0   140.24900    35.399655   80.0   109.00   141.0
# n_cores        2000.0     4.52050     2.287837    1.0     3.00     4.0
# pc             2000.0     9.91650     6.064315    0.0     5.00    10.0
# px_height      2000.0   645.10800   443.780811    0.0   282.75   564.0
# ...

# %%
mob_train.value_counts()
# Out:
# battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  mobile_wt  n_cores  pc  px_height  px_width  ram   sc_h  sc_w  talk_time  three_g  touch_screen  wifi  price_range
# 501            0     2.3          0         12  1       54          0.3    131        4        19  504        1089      2346  13    12    2          1        0             1     1              1
# 1494           0     1.9          0         2   1       47          0.4    129        2        9   207        1177      3202  13    1     14         1        0             0     3              1
# 1504           0     1.9          1         7   1       25          0.3    152        4        9   395        1853      1788  13    11    13         1        0             1     1              1
#                      1.5          0         12  1       34          0.7    142        8        15  507        973       2806  7     2     7          1        0             1     2              1
# ...

# %%
mob_test=pd.read_csv("mobile_price_test.csv")

# %%
mob_test.head()
# Out:
#    id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0   1           1043     1          1.8         1  14       0           5
# 1   2            841     1          0.5         1   4       1          61
# 2   3           1807     1          2.8         0   1       0          27
# 3   4           1546     0          0.5         1  18       1          25
# 4   5           1434     0          1.4         0  11       1          49
#
#    m_dep  mobile_wt  ...  pc  px_height  px_width   ram  sc_h  sc_w  \
# 0    0.1        193  ...  16        226      1412  3476    12     7
# 1    0.8        191  ...  12        746       857  3895     6     0
# 2    0.9        186  ...   4       1270      1366  2396    17    10
# 3    0.5         96  ...  20        295      1752  3893    10     0
# 4    0.5        108  ...  18        749       810  1773    15     8
#
#    talk_time  three_g  touch_screen  wifi
# 0          2        0             1     0
# ...

# %%
len(mob_train.columns)
# Out:
# 21

# %%
len(mob_train)
# Out:
# 2000

# %%
#EDA checking 
train_data=mob_train.copy()

# %%
#missing value or nulls
train_data.isnull().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
correl = mob_train.corr()
correl['price_range']
# Out:
# battery_power    0.200723
# blue             0.020573
# clock_speed     -0.006606
# dual_sim         0.017444
# fc               0.021998
# four_g           0.014772
# int_memory       0.044435
# m_dep            0.000853
# mobile_wt       -0.030302
# n_cores          0.004399
# pc               0.033599
# px_height        0.148858
# px_width         0.165818
# ram              0.917046
# sc_h             0.022986
# sc_w             0.038711
# talk_time        0.021859
# three_g          0.023611
# touch_screen    -0.030411
# wifi             0.018785
# price_range      1.000000
# Name: price_range, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(20,8))
sns.heatmap(correl,annot=True,cmap='PuBu')
# Out:
# <Axes: >

# %%
mob_train['price_range'].value_counts()
# Out:
# price_range
# 1    500
# 2    500
# 3    500
# 0    500
# Name: count, dtype: int64

# %%
sns.countplot(mob_train['price_range'])
plt.title('Mobile Price Ranges')
# Out:
# Text(0.5, 1.0, 'Mobile Price Ranges')

# %%
plt.figure(figsize=(12,8))

sns.countplot(data=mob_train, x='n_cores')
plt.title('Number of Cores')
# Out:
# Text(0.5, 1.0, 'Number of Cores')

# %%
plt.figure(figsize=(15,10))
sns.countplot(data=mob_train,x='n_cores',hue='price_range')
plt.title('Number of Cores Plot')
# Out:
# Text(0.5, 1.0, 'Number of Cores Plot')

# %%
sns.histplot(data=mob_train, x='mobile_wt', color='darkgreen')
# Out:
# <Axes: xlabel='mobile_wt', ylabel='Count'>

# %%
sns.histplot(data=mob_train,x='mobile_wt',palette='gist_rainbow',hue='price_range')
# Out:
# <Axes: xlabel='mobile_wt', ylabel='Count'>

# %%
sns.histplot(data=mob_train,x='ram',palette='PRGns')
# Out:
# C:\Users\amazon\AppData\Local\Temp\ipykernel_3956\3049432002.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data=mob_train,x='ram',palette='PRGns')
# <Axes: xlabel='ram', ylabel='Count'>

# %%
sns.histplot(data=mob_train,x='ram',palette='PRGn',hue='price_range')
# Out:
# <Axes: xlabel='ram', ylabel='Count'>

# %%
sns.barplot(data=mob_train,x='n_cores',y='ram')
# Out:
# <Axes: xlabel='n_cores', ylabel='ram'>

# %%
sns.scatterplot(data=mob_train,x='pc',y='fc')
# Out:
# <Axes: xlabel='pc', ylabel='fc'>

# %%
plt.figure(figsize=(15,10))
sns.scatterplot(data=mob_train,x='px_height',y='px_width',hue='price_range')
# Out:
# <Axes: xlabel='px_height', ylabel='px_width'>

# %%
sns.scatterplot(data=mob_train,x='battery_power',y='talk_time')
# Out:
# <Axes: xlabel='battery_power', ylabel='talk_time'>

# %%
#mobile with no bluetooth
blue_count = mob_train['blue'].value_counts()

print("The number of mobiles that have bluetooth: {}\nThe number of mobiles that don't have bluetooth: {}".format(blue_count[1], blue_count[0]))

blue_count.plot(kind='pie')
# Out:
# The number of mobiles that have bluetooth: 990
# The number of mobiles that don't have bluetooth: 1010
# <Axes: ylabel='count'>

# %%
#don'nt have sim card
sim_count = mob_train['dual_sim'].value_counts()

print("The number of mobiles that have dual sim capacity: {}\nThe number of mobiles that don't have dual sim capacity: {}".format(sim_count[1], sim_count[0]))

sim_count.plot(kind='pie')
# Out:
# The number of mobiles that have dual sim capacity: 1019
# The number of mobiles that don't have dual sim capacity: 981
# <Axes: ylabel='count'>

# %%
#mobile don'nt support 3g 
count_3g = mob_train['three_g'].value_counts()

print("The number of mobiles that have 3G capacity: {}\nThe number of mobiles that don't have 3G capacity: {}".format(count_3g[1], count_3g[0]))

count_3g.plot(kind='pie')
# Out:
# The number of mobiles that have 3G capacity: 1523
# The number of mobiles that don't have 3G capacity: 477
# <Axes: ylabel='count'>

# %%
sns.pairplot(mob_train, vars=['n_cores', 'wifi', 'price_range', 'dual_sim', 'ram', 'three_g'])

# %%
train_input_data = mob_train.drop('price_range', axis=1)
train_labels = mob_train['price_range']

# %%
from sklearn.preprocessing import MinMaxScaler #Normalization
scaler=MinMaxScaler()
scaler.fit(train_input_data)
train_input_data=scaler.transform(train_input_data)

# %%
from sklearn.linear_model import LogisticRegression
log_model=LogisticRegression()
log_model.fit(train_input_data,train_labels)
# Out:
# LogisticRegression()

# %%
log_model.score(train_input_data,train_labels)
# Out:
# 0.947

# %%
from sklearn.linear_model import SGDClassifier
sgd_model=SGDClassifier()
sgd_model.fit(train_input_data,train_labels)
# Out:
# SGDClassifier()

# %%
sgd_model.score(train_input_data,train_labels)
# Out:
# 0.7505

# %%
from sklearn.tree import DecisionTreeClassifier
tree_model=DecisionTreeClassifier()
tree_model.fit(train_input_data,train_labels)
# Out:
# DecisionTreeClassifier()

# %%
tree_model.score(train_input_data,train_labels)
# Out:
# 1.0

# %%
#Model Evaluation
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.model_selection import cross_val_score
log_score=cross_val_score(log_model,train_input_data,train_labels,cv=10)

# %%
log_score
# Out:
# array([0.915, 0.94 , 0.91 , 0.93 , 0.935, 0.94 , 0.92 , 0.925, 0.91 ,
#        0.92 ])

# %%
log_score.mean()
# Out:
# 0.9245000000000001

# %%
from sklearn.model_selection import cross_val_score
sgd_scores=cross_val_score(sgd_model,train_input_data,train_labels,cv=10)

# %%
sgd_scores
# Out:
# array([0.735, 0.705, 0.74 , 0.795, 0.805, 0.765, 0.825, 0.725, 0.715,
#        0.745])

# %%
sgd_scores.mean()
# Out:
# 0.7555000000000001

# %%
from sklearn.model_selection import cross_val_score
tree_scores=cross_val_score(tree_model,train_input_data,train_labels,cv=10)

# %%
tree_scores
# Out:
# array([0.825, 0.865, 0.845, 0.83 , 0.86 , 0.84 , 0.83 , 0.805, 0.865,
#        0.8  ])

# %%
tree_scores.mean()
# Out:
# 0.8365

# %%
#cross validation we get that tree method also not good so we consider logistic regression now apply prediction on test data
from sklearn.model_selection import cross_val_predict
predict_on_train=cross_val_predict(log_model,train_input_data,train_labels,cv=10)

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix=confusion_matrix(train_labels,predict_on_train)

# %%
confusion_matrix
# Out:
# array([[488,  12,   0,   0],
#        [ 31, 441,  28,   0],
#        [  0,  35, 430,  35],
#        [  0,   0,  10, 490]], dtype=int64)

# %%
sns.heatmap(confusion_matrix,annot=True,cmap='PuBu')
# Out:
# <Axes: >

# %%
from sklearn.metrics import accuracy_score
accuracy_score(train_labels,predict_on_train)
# Out:
# 0.9245

# %%
from sklearn.metrics import classification_report
print(classification_report(train_labels,predict_on_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96       500
#            1       0.90      0.88      0.89       500
#            2       0.92      0.86      0.89       500
#            3       0.93      0.98      0.96       500
#
#     accuracy                           0.92      2000
#    macro avg       0.92      0.92      0.92      2000
# weighted avg       0.92      0.92      0.92      2000
